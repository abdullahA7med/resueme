# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullahA7med/resueme/blob/main/coffe_case.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()
# %matplotlib inline

# %%
df = pd.read_csv('/content/drive/MyDrive/DataSet/Coffe_sales.csv')
df.head()
# Out:
#    hour_of_day cash_type  money    coffee_name Time_of_Day Weekday Month_name  \
# 0           10      card   38.7          Latte     Morning     Fri        Mar
# 1           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 2           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 3           13      card   28.9      Americano   Afternoon     Fri        Mar
# 4           13      card   38.7          Latte   Afternoon     Fri        Mar
#
#    Weekdaysort  Monthsort        Date             Time
# 0            5          3  2024-03-01  10:15:50.520000
# 1            5          3  2024-03-01  12:19:22.539000
# 2            5          3  2024-03-01  12:20:18.089000
# 3            5          3  2024-03-01  13:46:33.006000
# 4            5          3  2024-03-01  13:48:14.626000

# %% [markdown]
# ### question
#
# 1) The type of coffee that achieved the highest sales. `coffee_name`
#
# 2) The time of day when the most sales are made. `Time_of_Day`
#
# 3) The type that achieved the highest sales price.
#
# 4) The most expensive type of coffee .
#
# 5) The month with the highest sales.
#
# 6) The season of the months that achieves the most sales.

# %% [markdown]
# ### Q1

# %%
df['coffee_name'].value_counts().sort_values(ascending=False)
# Out:
# coffee_name
# Americano with Milk    809
# Latte                  757
# Americano              564
# Cappuccino             486
# Cortado                287
# Hot Chocolate          276
# Cocoa                  239
# Espresso               129
# Name: count, dtype: int64

# %% [markdown]
# ### Q2

# %%
df['Time_of_Day'].value_counts()
# Out:
# Time_of_Day
# Afternoon    1205
# Morning      1181
# Night        1161
# Name: count, dtype: int64

# %% [markdown]
# ### Q4

# %%
df['money'].value_counts().sort_values(ascending=False)
# Out:
# money
# 35.76    1014
# 32.82     490
# 25.96     459
# 30.86     389
# 27.92     334
# 37.72     273
# 23.02     208
# 38.70     128
# 28.90      93
# 21.06      59
# 33.80      51
# 18.12      36
# 24.00      13
# Name: count, dtype: int64

# %%
df[['money','coffee_name']]
# Out:
#       money    coffee_name
# 0     38.70          Latte
# 1     38.70  Hot Chocolate
# 2     38.70  Hot Chocolate
# 3     28.90      Americano
# 4     38.70          Latte
# ...     ...            ...
# 3542  35.76     Cappuccino
# 3543  35.76          Cocoa
# 3544  35.76          Cocoa
# 3545  25.96      Americano
# 3546  35.76          Latte
#
# [3547 rows x 2 columns]

# %%
df.head()
# Out:
#    hour_of_day cash_type  money    coffee_name Time_of_Day Weekday Month_name  \
# 0           10      card   38.7          Latte     Morning     Fri        Mar
# 1           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 2           12      card   38.7  Hot Chocolate   Afternoon     Fri        Mar
# 3           13      card   28.9      Americano   Afternoon     Fri        Mar
# 4           13      card   38.7          Latte   Afternoon     Fri        Mar
#
#    Weekdaysort  Monthsort        Date             Time
# 0            5          3  2024-03-01  10:15:50.520000
# 1            5          3  2024-03-01  12:19:22.539000
# 2            5          3  2024-03-01  12:20:18.089000
# 3            5          3  2024-03-01  13:46:33.006000
# 4            5          3  2024-03-01  13:48:14.626000

# %%
df.pivot_table(index='coffee_name',values='money').sort_values(by='money',ascending=False)
# Out:
#                          money
# coffee_name
# Hot Chocolate        35.990797
# Cappuccino           35.883004
# Cocoa                35.653389
# Latte                35.502378
# Americano with Milk  30.594710
# Americano            25.975638
# Cortado              25.731220
# Espresso             20.854884

# %% [markdown]
# ### Q5

# %%
df['Month_name'].value_counts()
# Out:
# Month_name
# Mar    494
# Oct    426
# Feb    423
# Sep    344
# Aug    272
# Dec    259
# Nov    259
# May    241
# Jul    237
# Jun    223
# Jan    201
# Apr    168
# Name: count, dtype: int64

# %% [markdown]
# ### Q6

# %%
df['seassion'] = df['Month_name'].map({'Jul':'summer', 'Jun':'summer', 'Aug':'summer',
                         'Dec':'winter', 'Feb':'winter', 'Jan':'winter',
                         'Mar':'spring', 'Apr':'spring', 'May':'spring',
                         'Oct':'Autumn', 'Nov':'Autumn', 'Sep':'Autumn'
                         })

# %%
df['seassion'].value_counts()
# Out:
# seassion
# Autumn    1029
# spring     903
# winter     883
# summer     732
# Name: count, dtype: int64

# %% [markdown]
# ---------------------------------------
#
#
# ## vis data

# %%
cust_color= ["#00a6fb","#0582ca","#006494","#003554","#051923"]

plt.figure(figsize=(10,5))

sns.barplot(x=df['seassion'].value_counts().index, y=df['seassion'].value_counts().values)


plt.show()

# %%
sns.displot(x)
